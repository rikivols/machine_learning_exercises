# %% [markdown]
# # Titanic - Machine Learning from Disaster
#
# This is a Machine learning exercise from Kaggle, where we're trying to predict who survived the Titanic disaster.
#
# https://www.kaggle.com/competitions/titanic
#
# ## Description
#
# The sinking of the Titanic is one of the most infamous shipwrecks in history.
#
# On April 15, 1912, during her maiden voyage, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg. Unfortunately, there weren’t enough lifeboats for everyone onboard, resulting in the death of 1502 out of 2224 passengers and crew.
#
# While there was some element of luck involved in surviving, it seems some groups of people were more likely to survive than others.
#
# In this challenge, we ask you to build a predictive model that answers the question: “what sorts of people were more likely to survive?” using passenger data (ie name, age, gender, socio-economic class, etc).
#
# # The data
# As we can see below, the data consists of multiple columns, such as passenger's cabin, name, gender, age, ticket, fare, etc.
#
# ## Output
# Our task is to predict, whether that person survived or not. The output should be in this CSV format:
# ```
# PassengerId,Survived
# 1000,0
# 1001,1
# ...
# ```
#
# ## Poznámky k odevzdání
#
#   * Řiďte se pokyny ze stránky https://courses.fit.cvut.cz/BI-ML1/homeworks/index.html.

# %%
# IMPORTS

import pandas
import pandas as pd
import numpy as np
import re
from typing import Union
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, ParameterGrid
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, roc_curve, roc_auc_score, accuracy_score, precision_score, f1_score
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from typing import Callable

random_seed = 11

# %matplotlib inline

# %%
# HELPERS

def get_frequency_counts(df: pd.DataFrame, column: str) -> dict:
    """
    This function calculates frequency of each value of a given column from a dataset
    """

    frequency_count = {}

    for ticket_id in df[column]:
        if ticket_id not in frequency_count:
            frequency_count[ticket_id] = 0

        frequency_count[ticket_id] += 1

    return frequency_count

# used for normalization
scaler = MinMaxScaler()

# %%
df = pd.read_csv('data.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1000 non-null   int64
#  1   Survived     1000 non-null   int64
#  2   pclass       1000 non-null   int64
#  3   name         1000 non-null   object
#  4   sex          1000 non-null   object
#  5   age          802 non-null    float64
#  6   sibsp        1000 non-null   int64
#  7   parch        1000 non-null   int64
#  8   ticket       1000 non-null   object
#  9   fare         999 non-null    float64
#  10  cabin        233 non-null    object
#  11  embarked     998 non-null    object
#  12  home.dest    566 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 101.7+ KB

# %% [markdown]
# <h2>Initial look at data and what will be processed</h2>
#
# As we can see above, a lot of values are missing and data are dirty, we need to process them.
#
# * pclass - ordinal value, all non null, no change needed
# * name - it doesn't seem useful to predict which name will survive and which not, we'll drop this value. We can extract title, more below
# * sex - nominal value, we'll apply one-hot encoding
# * age - missing values, obviously a very useful metric, we'll predict missing values later
# * sibsp - no change needed
# * parch - no change needed
# * ticket - we can extract useful information, more below
# * fare - One value is missing. We'll need to fill it, more below
# * cabin - a lot of values are missing, but there are still some values that are useful, more below
# * embarked - nominal value, some values missing, more below
# * home.dest - a lot of values are missing. The data is very dirty, often there's only 1 value, where we don't know what's home and what's dest, we'll
# remove it

# %% [markdown]
# <h2>Processing data</h2>
#
# Now we can finally start to process our data and fill the necessary missing values

# %% [markdown]
# <h3>Processing Name</h3>
#
# It doesn't seem useful to predict which name will survive and which not, we'll drop this value. However, a name also contains a title of that person, which
# can tell us useful things like marital status.

# %%
def find_title(name: str):
    titles = re.findall(r"[A-Z]\S+\.", name)
    if titles:
        return titles[0]
    return "Other"


df["name"].apply(find_title).value_counts()
# Out:
# name
# Mr.          566
# Miss.        210
# Mrs.         155
# Master.       45
# Dr.            7
# Rev.           4
# Col.           4
# Mlle.          2
# Sir.           1
# Capt.          1
# Dona.          1
# Ms.            1
# Countess.      1
# Mme.           1
# Major.         1
# Name: count, dtype: int64

# %% [markdown]
# As we can see, there are only 4 common titles, others are quire rare and not statistically significant.
#
# Some titles mean the same thing, but are in a different language, like Mlle. -> Miss., so we'll translate those.
#
# Capt. seems also as an interesting title, as captains leave the boat as the latest, however we only have 1, and it's a passenger that paid a fare,
# it shouldn't decrease their survival likelihood.
#
# The full function is below

# %%
def get_title(name: str):
    """
    :param name: Person's name
    :return: Person's title, or 'Other' if it's a rare title.
    """

    translate_title = {
        "Mlle.": "Miss.",
        "Dona.": "Mrs.",
        "Mme.": "Mrs."
    }

    useful_titles = {"Mr.", "Miss.", "Mrs.", "Master.", "Mlle.", "Dona.", "Mme."}

    title = ""
    for useful_title in useful_titles:
        if useful_title in name:
            title = useful_title

    if title:
        if title in translate_title:
            title = translate_title[title]
        return title[:-1]
    return "Other"

df["title"] = df["name"].apply(get_title)
df.drop("name", axis=1)

# we'll plot the titles and their survival rate to see if they're statistically significant
graph = sns.catplot(y="title", hue="Survived", data=df.sort_values(by='title'), kind="count")
graph.set(ylabel="Person's title", title="Survival rate per title");

# %% [markdown]
# <h3> Processing ticket </h3>
#
# They’re usually unique numbers, we wouldn’t get much value out of it. However, there seems to be 2 types of tickets, one which starts with a number and second one which starts
# with a letter. There may be some hidden value there, we’ll split ticket into ones that start with a number and ones that start with a letter.

# %%
def categorize_ticket(ticket: Union[str, float]) -> str:
    if ticket == np.nan:  # protection in case future data have null
        return "No"
    ticket = ticket.strip()
    if ticket[0].isdigit():
        return "Yes"
    return "No"

df["ticket_starts_with_letter"] = df["ticket"].apply(categorize_ticket)
print(df["ticket"].value_counts())
sns.countplot(x='Survived', hue ='ticket_starts_with_letter', data=df);
# Out:
# ticket
# CA. 2343            9
# PC 17608            7
# CA 2144             6
# 347088              6
# 347077              6
#                    ..
# SOTON/O2 3101272    1
# 14312               1
# 368364              1
# CA. 2314            1
# 343095              1
# Name: count, Length: 746, dtype: int64

# %% [markdown]
# Based on the graph above, the letter of a ticket doesn't seem to be important.
#
# However, we can see that some people have the same ticket - they're sharing one!
# We can see if that information could have any impact.

# %%
def find_if_duplicate_ticket(df: pandas.DataFrame):
    frequency_count = get_frequency_counts(df, "ticket")

    df["shares_ticket"] = df["ticket"].apply(lambda x: "Yes" if frequency_count[x] > 1 else "No")
    return df

df = find_if_duplicate_ticket(df)
df["shares_ticket"].value_counts()
df.drop("ticket", axis=1)

sns.countplot(x='Survived', hue ='shares_ticket', data=df);

# %% [markdown]
# It looks like people who shared ticket were more likely to survive!
#
# We'll use the shared ticket value instead. We won't be using ticket's letter.

# %% [markdown]
# <h3>Processing Fare</h3>
#
# One value is missing. I’ve also seen instances where fare was 0. I won’t be changing this value and assuming that it was for free. There are no negative numbers, but if they were,
#  I’m assuming that a passenger got paid.

# %%
sns.histplot(df['fare'], bins=30, kde=False);

# %% [markdown]
# Fare prices seem to be skewed left, that's why we'll use median to fill the missing values, and not mean.

# %%
df['fare'] = df['fare'].fillna(df['fare'].median())

# %% [markdown]
# <h3>Processing cabin</h3>
#
# Most values are missing, that's why it's not reasonable to work with the text. Instead, if cabin is not nan, we can take it as a person was in the cabin, otherwise they weren't.

# %%
df["is_in_cabin"] = df["cabin"].apply(lambda x: "In cabin" if type(x) == str else "Not in cabin")
sns.countplot(x='Survived', hue='is_in_cabin', data=df);

# %% [markdown]
# It seems like people in cabin are more likely to survive! We'll be including this value.

# %% [markdown]
# Embarked
#
# We have 2 missing values. As a person must've embarked from somewhere, because they're already on the boat, we can conclude that these values are just missing and
# not intentionally nan. That's why we need to replace the nan values.
#
# We'll replace the data with the most used one.

# %%
sns.countplot(x='embarked', data=df);

# %%
frequency_counts = get_frequency_counts(df, "embarked")
most_freq_embarked = max(frequency_counts, key=frequency_counts.get)
df["embarked"] = df["embarked"].apply(lambda x: most_freq_embarked if x == np.nan else x)

# %% [markdown]
# <h2>Splitting Data</h2>
#
# Before applying our before-mentioned functions and processing the data, we need to split the data, because we don't want to risk over-fitting our model.
#
# Since we're going to fill the missing data, we'll first split our data into training and testing set. We want to simulate the reality as much as possible while testing.
#
# We're not splitting the data into a validation part, because we'll be using cross validation to find the optimal hyperparameters.

# %%
# discard all previous changes, they were for explaining purposes
df = pd.read_csv('data.csv')

Xtrain, Xtest, Ytrain, Ytest = train_test_split(
    df.drop('Survived', axis=1), df.Survived, test_size=0.2, random_state=random_seed
)

# %% [markdown]
# <h2> Processing data - bringing it together </h2>
#
# Now let's combine all the data processing above into a function.
#
# We'll fill age after processing the data.

# %%
def process_data(df: pandas.DataFrame) -> pandas.DataFrame:
    """
    Processes the raw loaded dataframe. Makes the data ready for training, uses one-hot encoding.

    :param df: Dataframe to process.
    :return: Processed dataframe
    """
    df.set_index("PassengerId", inplace=True)

    # title transformations
    df["title"] = df["name"].apply(get_title)
    df = df.drop("name", axis=1)

    # ticket transformations
    df = find_if_duplicate_ticket(df)
    df = df.drop("ticket", axis=1)

    # fare transformations
    df['fare'] = df['fare'].fillna(df['fare'].median())

    # cabin transformations
    df["is_in_cabin"] = df["cabin"].apply(lambda x: "In cabin" if type(x) == str else "Not in cabin")
    df = df.drop("cabin", axis=1)

    # embarked transformations
    frequency_counts = get_frequency_counts(df, "embarked")
    most_freq_embarked = max(frequency_counts, key=frequency_counts.get)
    df["embarked"] = df["embarked"].apply(lambda x: most_freq_embarked if x == np.nan else x)

    df = df.drop("home.dest", axis=1)

    # since all the data that are object are nominal now, we can apply one-hot encoding at the end to get the dummy values.
    df = pd.get_dummies(df)

    return df

Xtrain = process_data(Xtrain)

# %% [markdown]
# <h3>Predict age</h3>
#
# We're going to use our existing data to predict the age of a person.
#
# We'll use a model that we'll train on the part of the data that contains the age to predict rows without age.
#
# I've tried to play around with DecisionTreeRegressor and KNN algorithm, however linear regression gave me the best results.
#
# Both DecisionTreeRegressor and KNN skewed the ages heavily from their original form. To maintain the data integrity, I've used linear regression. We can use linear regression
# because the columns aren't too heavily correlated. Title could correlate with sex, however that shouldn't break the model too much.

# %%
sns.histplot(Xtrain['age'], bins=30, kde=False);

# %%
def get_trained_model(df: pd.DataFrame, plot_linear_regression=False) -> LinearRegression:
    """
    Function to train a model that is able to predict the age of a person.

    :param df: dataframe to train on
    :param plot_linear_regression: if we should also plot a graph of the predicted ages.
    :return: a model able to predict age of a person.
    """

    # split the data into ones we'll train on and ones we'll predict
    # Using copy() to prevent warnings
    df_with_age = df[df['age'].notna()].copy()
    # since we'll want to work with ages as whole numbers, we'll get rid of the decimal places for training
    df_with_age["age"] = df_with_age["age"].astype(int)

    # split the data into X and Y
    Xtrain, Xtest, Ytrain, Ytest = train_test_split(
        df_with_age.drop('age', axis=1), df_with_age.age, test_size=0.2, random_state=random_seed
    )

    # normalize the data
    Xtrain = scaler.fit_transform(Xtrain)
    Xtest = scaler.fit_transform(Xtest)

    # find the most optimal depth
    decision_regressor = LinearRegression()
    # decision_regressor = DecisionTreeRegressor(max_depth=best_depth)
    decision_regressor.fit(Xtrain, Ytrain)

    predicted_ages = decision_regressor.predict(Xtest)
    if plot_linear_regression:
        plt.scatter(Ytest, predicted_ages)
        plt.plot([0,50], [0,50], 'r')
        plt.show()

    print('Squared error of predict age:', np.sqrt(mean_squared_error(np.array(Ytest), predicted_ages)))

    return decision_regressor


def predict_age(df: pd.DataFrame, trained_model: LinearRegression) -> (pd.DataFrame, pd.DataFrame):
    """
    A function to predict the age of a person with a given model

    :param df: dataframe to predict the age on
    :param trained_model: the trained model that we'll use for predicting
    :return: (dataframe with the filled ages, only rows from a dataframe that were predicted)
    """

    df_with_age = df[df['age'].notna()].copy()
    df_without_age = df[df['age'].isna()].copy()

    Xpredict = df_without_age.drop("age", axis=1)
    Xpredict = scaler.fit_transform(Xpredict)

    predicted_age = trained_model.predict(Xpredict)
    df_without_age["age"] = predicted_age

    df_to_attach = pd.concat([df_with_age, df_without_age], axis=0)
    df["age"] = df_to_attach["age"]

    # get rid of floats, round the age (since we did that for the training data)
    df["age"] = df["age"].apply(lambda x: int(round(x)))

    return df, df_without_age


age_predicting_model = get_trained_model(Xtrain, plot_linear_regression=True)
Xtrain, Xtrain_predicted_age = predict_age(Xtrain, age_predicting_model)
# Out:
# Squared error of predict age: 11.496817420671842

# %%
sns.histplot(df['age'], bins=30, kde=False)

sns.histplot(Xtrain_predicted_age['age'], bins=30, kde=False)

Xtrain_predicted_age['age'].value_counts()
# Out:
# age
# 29.1250    35
# 35.2500    19
# 22.5625    14
# 27.7500    10
# 28.6250     4
#            ..
# 39.1250     1
# 31.5625     1
# 34.2500     1
# 2.1250      1
# 20.1875     1
# Name: count, Length: 67, dtype: int64

# %% [markdown]
# We can see that the composition of the ages didn't change too much even after predicting. With a squared error of 11, linear regression had realistic predictions.

# %%
Xtrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 832 to 921
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pclass                    800 non-null    int64
#  1   age                       800 non-null    int64
#  2   sibsp                     800 non-null    int64
#  3   parch                     800 non-null    int64
#  4   fare                      800 non-null    float64
#  5   sex_female                800 non-null    bool
#  6   sex_male                  800 non-null    bool
#  7   embarked_C                800 non-null    bool
#  8   embarked_Q                800 non-null    bool
#  9   embarked_S                800 non-null    bool
#  10  title_Master              800 non-null    bool
#  11  title_Miss                800 non-null    bool
#  12  title_Mr                  800 non-null    bool
#  13  title_Mrs                 800 non-null    bool
#  14  title_Other               800 non-null    bool
#  15  shares_ticket_No          800 non-null    bool
#  16  shares_ticket_Yes         800 non-null    bool
#  17  is_in_cabin_In cabin      800 non-null    bool
#  18  is_in_cabin_Not in cabin  800 non-null    bool
# dtypes: bool(14), float64(1), int64(4)
# memory usage: 48.4 KB

# %% [markdown]
# We can see that we no longer have any null values in our training data.

# %% [markdown]
# <h2>Normalization</h2>
#
# We want to normalize the data to avoid outliners from skewing our model data. For example the "fare" was heavily skewed towards cheaper prices, but there were some people
# who paid a lot of money for the ticket.

# %%
Xtrain = pd.DataFrame(scaler.fit_transform(Xtrain), index=Xtrain.index, columns=Xtrain.columns)

# %% [markdown]
# <h2>Decision tree</h2>
#
# Now we're going to apply a decision tree algorithm to the processed and normalized training data to teach the model to predict who survives.
#
# Decision tree is an algorithm where each node represents a test on the attribute (sex is male) and each branch represents an outcome of such test (true, false).
# You can trace back each decision by the path from the leaf to the root. Decision tree makes it easier to see which parameters were important and which weren't.
#
# Decision trees are good when:
# * We have a lot of columns, decision trees can be good at identifying what variables to discard and what are more important
# * When we have a lot of categorical data (the increase of columns from dummy values won't pose a problem)
# * The data set is huge - they require less RAM and computational complexity than KNN
#
# Potential disadvantages:
# * A tree can easily become biased, when disregarding variables
# * Over-fitting - a tree can give too much weight to a certain column / data where it shouldn't be
#
# Trees are very useful when we need to correctly interpret the mixed data and being biased towards a certain column / variable won't pose an issue.

# %% [markdown]
# <h3>Cross validation</h3>
#
# We're going to use cross validation to pick the optimal hyperparameters for our decision tree.
#
# We'll get the best combination of max depth of a tree and criterion (The function to measure the quality of a split).

# %%
def cross_validate(parameters, model_class: Callable):
    """
    Picks the best hyperparameters for the given model
    """

    param_comb = ParameterGrid(parameters)

    validation_means = []
    for kwargs in param_comb:
        model = model_class(**kwargs)
        # cross validation
        fold_acc = cross_val_score(model, Xtrain, Ytrain, cv=5)
        validation_means.append(np.mean(fold_acc))

    best_params = param_comb[np.argmax(validation_means)]
    best_score = max(validation_means)

    print(f"Cross validation completed for {str(model_class)}, best hyperparameters: {best_params}, best validation score: {best_score}")

    return best_params, best_score, validation_means

decision_tree_max_depth = 50

param_grid = {
    'max_depth': range(1, decision_tree_max_depth),
    'criterion': ['gini', 'entropy', 'log_loss'],
    'random_state': [random_seed]
}

best_tree_params, best_tree_score, all_metrics = cross_validate(param_grid, DecisionTreeClassifier)
# Out:
# Cross validation completed for <class 'sklearn.tree._classes.DecisionTreeClassifier'>, best hyperparameters: {'random_state': 11, 'max_depth': 5, 'criterion': 'entropy'}, best validation score: 0.7949999999999999

# %% [markdown]
# Plotting the hyperparameters:

# %%
fig, ax = plt.subplots(3, 1, figsize=(12, 12))

ax[0].plot(range(1, decision_tree_max_depth), all_metrics[:decision_tree_max_depth-1], 'ob-')
ax[0].set_title('Gini index')
ax[0].set_xlabel('depth')
ax[0].set_ylabel('accuracy')

ax[1].plot(range(1, decision_tree_max_depth), all_metrics[decision_tree_max_depth-1:decision_tree_max_depth*2-2], 'ob-')
ax[1].set_title('Entropy')
ax[1].set_xlabel('depth')
ax[1].set_ylabel('accuracy')

ax[2].plot(range(1, decision_tree_max_depth), all_metrics[decision_tree_max_depth*2-2:], 'ob-')
ax[2].set_title('Log loss')
ax[2].set_xlabel('depth')
ax[2].set_ylabel('accuracy')

plt.tight_layout()

# %% [markdown]
# <h3>Training the model</h3>
#
# Lastly, we pick the best hyperparameters for the model and train it

# %%
# train the best model
best_tree_model = DecisionTreeClassifier(**best_tree_params)
best_tree_model.fit(Xtrain, Ytrain);

# %% [markdown]
# <h2>K-Nearest Neighbors </h2>
#
# Now we're going to train on the same data with the K-Nearest Neighbors algorithm.
#
# How it works:
# * compute the distance of a data point to other data points.
# * Find the k-nearest data points.
# * Assign the most frequent label from k neighbors.
#
# KNN is good when:
# * Compared to decision trees, there's no training needed, we're only waiting for the prediction time
# * Doesn't make assumptions, less prone to over-fitting and bias
#
# Potential disadvantages:
# * Curse of dimensionality - the more columns we have, the further away our data are from each other, our performance is decreasing
# * Large datasets would require a lot more computational power to predict than trees
#
# KNN is useful when we don't have many columns and all have similar importance.

# %%
knn_max_neighbors = 50

param_grid = {
    'n_neighbors': range(1, knn_max_neighbors),
    'weights': ['uniform', 'distance'],
    "p": [1, 2]  # manhattan_distance, euclidean_distance
}

best_knn_params, best_knn_score, all_metrics = cross_validate(param_grid, KNeighborsClassifier)

# train the best model
best_knn_model = KNeighborsClassifier(**best_knn_params)
best_knn_model.fit(Xtrain, Ytrain);
# Out:
# Cross validation completed for <class 'sklearn.neighbors._classification.KNeighborsClassifier'>, best hyperparameters: {'weights': 'uniform', 'p': 1, 'n_neighbors': 7}, best validation score: 0.80375

# %%
plt.figure(figsize=(20,6))
plt.plot(range(1, knn_max_neighbors), all_metrics[0::4], 'ob-')
plt.title("KNN, weights: uniform, p: 1")
plt.xlabel('n neighbors')
plt.ylabel('accuracy')
plt.legend(['test data']);

# %% [markdown]
# <h2>Analysis of the model's performance</h2>
#
# We're going to analyse how well our model performs on a new data.
#
# We'll use the test set, that we split from all the data in the beginning.

# %% [markdown]
# At first, we'll apply all the data transform, normalisation, age prediction to test data, just as we did for the train data.

# %%
# apply data processing
Xtest = process_data(Xtest)
# fill ages
Xtest, _ = predict_age(Xtest, age_predicting_model)
# apply normalization
Xtest = pd.DataFrame(scaler.fit_transform(Xtest), index=Xtest.index, columns=Xtest.columns)

# %% [markdown]
# <h3>Evaluation of Decision tree classifier</h3>
#
# We're going to plot the ROC curve and calculate various metrics on the test data to see how well our model performs

# %%
def plot_roc(model):
    Yprobability = model.predict_proba(Xtest)
    p1_hat = Yprobability[:,1]

    fpr, tpr, thresholds = roc_curve(Ytest, p1_hat)

    AUC = roc_auc_score(Ytest, p1_hat)

    plt.figure()
    plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")
    plt.plot(fpr, tpr, color="darkorange", lw=2, label = f"ROC curve (AUC = {AUC:.3f})")
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.title("ROC curve")
    plt.legend(loc="lower right")
    plt.show()

plot_roc(best_tree_model)

# %%
Ypredicted = best_tree_model.predict(Xtest)

print(f'Accuracy score (test): {accuracy_score(Ytest, Ypredicted):.4f}')
print(f'Precision score (test): {precision_score(Ytest, Ypredicted):.4f}')
print(f'F1 score (test): {f1_score(Ytest, Ypredicted):.4f}')
# Out:
# Accuracy score (test): 0.7750
# Precision score (test): 0.7159
# F1 score (test): 0.7368

# %% [markdown]
# <h3>Evaluation of K-Nearest Neighbors</h3>

# %%
plot_roc(best_knn_model)

# %%
Ypredicted = best_knn_model.predict(Xtest)

print(f'Accuracy score (test): {accuracy_score(Ytest, Ypredicted):.4f}')
print(f'Precision score (test): {precision_score(Ytest, Ypredicted):.4f}')
print(f'F1 score (test): {f1_score(Ytest, Ypredicted):.4f}')
# Out:
# Accuracy score (test): 0.7800
# Precision score (test): 0.7600
# F1 score (test): 0.7215

# %% [markdown]
# <h2>Conclusion</h2>
#
# Both models performed good, with F1, accuracy, precision, AUC score being above 0.7 for both of them. Each model had their own metrics where they were better:
# * Cross validation score (for best hyperparameters) - 0.795 (tree) vs 0.804 (knn)
# * Accuracy score of test data - 0.775 (tree) vs 0.780 (knn)
# * Precision score of test data - 0.716 (tree) - 0.76 (knn)
# * F1 score of test data - 0.737 (tree) vs 0.722 (knn)
# * AUC of test data - 0.805 (tree) vs 0.822 (knn)
#
# Accuracy score is very slightly better for KNN, indicating that KNN is better at making overall predictions.
# Precision score is better for KNN, which indicates that KNN is better at making positive predictions.
# F1 score is better for tree, which indicates that tree is better at avoiding false negatives.
# AUC is better for KNN, which indicates that the overall ability to distinguish between alive and dead person is better.
#
# Both models performing similarly well isn't that unexpected, since:
# * A case for KNN: we have a lot of important variables, like age, gender, wealth to determine who survived, it makes sense that KNN would perform better since it doesn't bias as much
# for 1 variable.
# * A case for tree: we have a lot of columns relative to the data size (dummy values...), it makes sense that tree would perform better, since dimensionally, neighbors in KNN
# are getting further apart and are decreasing the performance.
#
# We can pick any of those models depending on what we want to accomplish.

# %%
df = pd.read_csv('data.csv')
sns.countplot(x='Survived', data=df);

# %% [markdown]
# Since our data is quite balanced, we'll use AUC (and accuracy score) as a better indicator and pick KNN algorithm for the final prediction.
#
# Our chance of accurately predicting is 78%

# %% [markdown]
# <h2>Populating evaluation dataset</h2>
#
# And at last, we'll use our best KNN model to fill the results csv.

# %%
df_result = pd.read_csv('evaluation.csv')
# process columns to better handle text, create dummy values
df_result = process_data(df_result)
# predict age with regression model from training data
df_result, _ = predict_age(df_result, age_predicting_model)
# normalize data
df_result = pd.DataFrame(scaler.fit_transform(df_result), index=df_result.index, columns=df_result.columns)
# make predictions
survival_predicted = best_knn_model.predict(df_result.copy())
df_result["Survived"] = survival_predicted

final_result = df_result[["Survived"]]

final_result.to_csv("results.csv")
